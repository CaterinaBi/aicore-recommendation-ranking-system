# %%
import pandas as pd

# %%
products_df = pd.read_csv("products.csv", sep=",")
products_df.head(600)
# Out:
#                                             Unnamed: 0  \
# 0                                                    0
# 1                                                    1
# 2                                                    2
# 3                                                    3
# 4                                                    4
# ..                                                 ...
# 595                                                293
# 596                                                294
# 597                                                295
# 598                                                 .
# 599  Any quantity available anywhere in Northern Ir...
#
#                                        id  \
# 0    243809c0-9cfc-4486-ad12-3b7a16605ba9
# 1    1c58d3f9-8b93-47ea-9415-204fcc2a22e6
# 2    860673f1-57f6-47ba-8d2f-13f9e05b8f9a
# 3    59948726-29be-4b35-ade5-bb2fd7331856
# 4    16dbc860-696e-4cda-93f6-4dd4926573fb
# ..                                    ...
# ...

# %%
# assigns operation to dataframe variable
products_df = products_df.dropna() # deletes columns where at least 1 item is missing

# %%
# cheks that NaN columns have been dropped
products_df.head(60)
# Out:
#    Unnamed: 0                                    id  \
# 0           0  243809c0-9cfc-4486-ad12-3b7a16605ba9
# 1           1  1c58d3f9-8b93-47ea-9415-204fcc2a22e6
# 2           2  860673f1-57f6-47ba-8d2f-13f9e05b8f9a
# 3           3  59948726-29be-4b35-ade5-bb2fd7331856
# 12          5  5707be4f-49d9-4feb-b2c8-aa0868405c65
# 13          6  d2244a7b-aef4-4495-aff7-0c55bf512d6e
# 14          7  485edc04-7bbc-430a-9430-f05a77f5a917
# 15          8  7e538445-c75e-4802-8dc5-a9083a802278
# 16          9  1a64843d-72f3-4141-946f-fa9b978fe755
# 17         10  ac514199-1ceb-4703-902d-4d8c55bea7e4
# 18         11  f36672f9-fbe5-40ac-8f5d-015c660c3304
# 19         12  5f5f57d7-778f-4336-bb10-b43863418c8c
# 20         13  c2c8949f-3cde-4651-a234-4a4a1b2a9ad4
# 21         14  8292aa4e-7f1b-4655-bf0e-f1f2c9e3ffaf
# 22         15  a7500af0-25a1-447d-a67a-c575a82f0657
# 23         16  53061acb-d253-41c2-8626-ea92e1f26c21
# 26         18  a68bf37d-e00f-4a33-b39f-540dd1102d28
# ...

# %%
products_df.dtypes #finds the object type for each column
# Out:
# Unnamed: 0             object
# id                     object
# product_name           object
# category               object
# product_description    object
# price                  object
# location               object
# dtype: object

# %%
products_df.info() # finds the object types and number of nulls
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6311 entries, 0 to 11317
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           6311 non-null   object
#  1   id                   6311 non-null   object
#  2   product_name         6311 non-null   object
#  3   category             6311 non-null   object
#  4   product_description  6311 non-null   object
#  5   price                6311 non-null   object
#  6   location             6311 non-null   object
# dtypes: object(7)
# memory usage: 394.4+ KB

# %%
# price column needs to be converted as a float
# if we try to sum objects, we don't get the expected result

# products_df['price'].sum() # throws error

# %%
products_df['price'] = products_df['price'].str.strip('£')
products_df = products_df.replace(',','', regex=True) # commas need to go to convert price string to float
products_df['price'] = products_df['price'].astype('float64')

# %%
products_df.head()
# Out:
#    Unnamed: 0                                    id  \
# 0           0  243809c0-9cfc-4486-ad12-3b7a16605ba9
# 1           1  1c58d3f9-8b93-47ea-9415-204fcc2a22e6
# 2           2  860673f1-57f6-47ba-8d2f-13f9e05b8f9a
# 3           3  59948726-29be-4b35-ade5-bb2fd7331856
# 12          5  5707be4f-49d9-4feb-b2c8-aa0868405c65
#
#                                          product_name  \
# 0   Mirror wall art | in Wokingham Berkshire | Gum...
# 1   Stainless Steel Food Steamer | in Inverness Hi...
# 2   Sun loungers | in Skegness Lincolnshire | Gumtree
# 3   Coffee side table from Ammunition ammo box hai...
# 12   Spotlights | in Newent Gloucestershire | Gumtree
#
#                                              category  \
# 0   Home & Garden / Dining Living Room Furniture /...
# 1               Home & Garden / Other Household Goods
# 2   Home & Garden / Garden & Patio / Outdoor Setti...
# 3   Home & Garden / Dining Living Room Furniture /...
# ...

# %%
# checks that the prices are now floats
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6311 entries, 0 to 11317
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           6311 non-null   object
#  1   id                   6311 non-null   object
#  2   product_name         6311 non-null   object
#  3   category             6311 non-null   object
#  4   product_description  6311 non-null   object
#  5   price                6311 non-null   float64
#  6   location             6311 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 394.4+ KB
